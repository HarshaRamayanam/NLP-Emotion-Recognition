# %% [markdown]
# **Note:** *Change to GPU runtime for faster execution*

# %% [markdown]
# # First, mount the drive to get access to dataset

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Load the dataset from drive

# %%
import os
import pandas as pd

# Specify the path to dataset and the file name
DATASET_DIR = os.path.join(os.getcwd(), r'drive/MyDrive/NLP Final Project/datasets/sentiment140_kaggle')
FILE = os.path.join(DATASET_DIR, r'Sentiment140.annotated.resampled.100000.csv')

# Open the csv file as a pandas DataFrame with specified columns
tweets_df = pd.read_csv(FILE, sep=',', encoding='utf-8')
tweets_df
# Out:
#         target                                              tweet     label
# 0            0      @mimsay   We'll miss you.  Congrats lil lady.  negative
# 1            0  Feeling sorry for myself today cos of my drunk...  negative
# 2            0  My computer won't let me online.   On laptop n...  negative
# 3            0  New Post and lots of sulking    http://tinyurl...  negative
# 4            0                               @purplepleather AWW   negative
# ...        ...                                                ...       ...
# 999995       4  @babygirlparis Ten bucks says I know where you...       joy
# 999996       4  is at the gym then off to cocoa beach for Sund...       joy
# 999997       4  @joek949 Morning you!    Might go to the beach...       joy
# 999998       0  maybe going to the beach after work, got 17kno...       joy
# 999999       4  @D_AMAZIN Won't I get arrested if I am naked o...       joy
#
# [1000000 rows x 3 columns]

# %% [markdown]
# # Cleaning the raw tweets

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer

nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %% [markdown]
# > Remove the word 'not' from stopwords as it specifies a negative emotion

# %%
all_stopwords = stopwords.words('english')
all_stopwords.remove('not')

def clean(tweet):

    # Remove @usermentions (for a tweet)
    tweet = re.sub('@[^\s]+',' ',tweet)

    # Remove urls (for a tweet)
    tweet = re.sub('((www\.[^\s]+)|(https?://[^\s]+))',' ',tweet)
    
    # Replace #word with word (for a tweet)
    tweet = re.sub(r'#([^\s]+)', r'\1', tweet)

    # Remove all remaining punctuations
    tweet = re.sub(r'[^a-zA-Z]', ' ', tweet)

    # Convert tweet to lowercase
    tweet = tweet.lower()
    
    # Remove stop words
    tweet = tweet.split()
    tweet = ' '.join([word for word in tweet if not word in set(all_stopwords)])
    
    return tweet

# %% [markdown]
# > Apply to the `clean` function to DataFrame

# %%
# %%time
tweets_df['cleaned_tweet'] = tweets_df['tweet'].apply(clean)
# Out:
# CPU times: user 47.1 s, sys: 83.6 ms, total: 47.2 s
# Wall time: 47.2 s

# %%
tweets_df
# Out:
#         target  ...                                      cleaned_tweet
# 0            0  ...                             miss congrats lil lady
# 1            0  ...  feeling sorry today cos drunken antics last ni...
# 2            0  ...  computer let online laptop not upload pics any...
# 3            0  ...                              new post lots sulking
# 4            0  ...                                                aww
# ...        ...  ...                                                ...
# 999995       4  ...  ten bucks says know going think let know bould...
# 999996       4  ...                      gym cocoa beach sunday funday
# 999997       4  ...                       morning might go beach think
# 999998       0  ...  maybe going beach work got knots wind today ho...
# 999999       4  ...                       get arrested naked beach lol
#
# [1000000 rows x 4 columns]

# %% [markdown]
# # Split the data into train set and test set

# %%
from sklearn.model_selection import train_test_split

X = tweets_df.cleaned_tweet.values
y = tweets_df.label.values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# # Specify the hyper parameters

# %%
MAX_VOCAB_SIZE = 20000
MAX_LEN = 1000

EMBEDDING_DIM = int(round(MAX_VOCAB_SIZE ** 0.25))

# %% [markdown]
# # Prepare the data for training

# %% [markdown]
# > **Tokenize**

# %%
# %%time
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer

tokenizer = Tokenizer(num_words=MAX_VOCAB_SIZE)
tokenizer.fit_on_texts(X_train)
# Out:
# CPU times: user 9.69 s, sys: 180 ms, total: 9.87 s
# Wall time: 9.89 s

# %% [markdown]
# > **Convert to sequences**

# %%
# %%time
X_train = tokenizer.texts_to_sequences(X_train)
X_test = tokenizer.texts_to_sequences(X_test)
# Out:
# CPU times: user 9.94 s, sys: 94.9 ms, total: 10 s
# Wall time: 10 s

# %% [markdown]
# > **Pad the sequences to convert all inputs to same shape**

# %%
# %%time
from tensorflow.keras.preprocessing.sequence import pad_sequences

X_train = pad_sequences(X_train, maxlen=MAX_LEN)
X_test = pad_sequences(X_test, maxlen=MAX_LEN)
# Out:
# CPU times: user 3.86 s, sys: 694 ms, total: 4.55 s
# Wall time: 4.55 s

# %% [markdown]
# > **Label encode the 10 classes and convert them to one-hot encodings**

# %%
from sklearn.preprocessing import LabelEncoder
from keras.utils.np_utils import to_categorical


encoder = LabelEncoder()
transformed_labels = encoder.fit_transform(tweets_df.label.values)

y_train = encoder.transform(y_train)
y_test = encoder.transform(y_test)

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# # CNN model for CARER

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.layers import Embedding
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Activation

# %% [markdown]
# > **Specify model parameters**

# %%
# FILTERS = 16
KERNEL_SIZE = 3

EPOCHS = 4
BATCH_SIZE = 128

# %% [markdown]
# > **Create a model**

# %%
model = Sequential([
    Embedding(MAX_VOCAB_SIZE, EMBEDDING_DIM, input_length=MAX_LEN),
    Conv1D(3, KERNEL_SIZE, padding='valid', activation='relu'),
    Conv1D(16, KERNEL_SIZE, padding='valid', activation='relu'),
    Activation('relu'),
    MaxPooling1D(3),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax'),
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 1000, 12)          240000
# _________________________________________________________________
# conv1d (Conv1D)              (None, 998, 3)            111
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 996, 16)           160
# _________________________________________________________________
# activation (Activation)      (None, 996, 16)           0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 332, 16)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 5312)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               2720256
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               65664
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 3,027,481
# Trainable params: 3,027,481
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# > **Compile the model**

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %% [markdown]
# > **Fit the model**

# %%
history = model.fit(X_train, y_train, batch_size=BATCH_SIZE, epochs=EPOCHS)
# Out:
# Epoch 1/4
# 6250/6250 [==============================] - 101s 11ms/step - loss: 1.3717 - accuracy: 0.4967
# Epoch 2/4
# 6250/6250 [==============================] - 70s 11ms/step - loss: 0.6494 - accuracy: 0.7973
# Epoch 3/4
# 6250/6250 [==============================] - 70s 11ms/step - loss: 0.5079 - accuracy: 0.8467
# Epoch 4/4
# 6250/6250 [==============================] - 71s 11ms/step - loss: 0.4420 - accuracy: 0.8660

# %% [markdown]
# > **Predict on test data**

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# # Classification report

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
import numpy as np

print("Report:\n")
average = 'macro'

print(f"Accuracy score  : {accuracy_score(np.argmax(y_test, axis=1), np.argmax(y_pred, axis=1))}")
print(f"Precision score : {precision_score(np.argmax(y_test, axis=1), np.argmax(y_pred, axis=1), average=average)}")
print(f"Recall score    : {recall_score(np.argmax(y_test, axis=1), np.argmax(y_pred, axis=1), average=average)}")
print(f"F1 score        : {f1_score(np.argmax(y_test, axis=1), np.argmax(y_pred, axis=1), average=average)}")
# Out:
# Report:
#
# Accuracy score  : 0.873485
# Precision score : 0.8698278799669801
# Recall score    : 0.8731960189738489
# F1 score        : 0.8686062327526759

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(np.argmax(y_test, axis=1), np.argmax(y_pred, axis=1))

plt.figure(figsize=(20, 5))

sns.heatmap(cm, fmt="d", annot=True, cmap='Blues', xticklabels=list(set(y)), yticklabels=list(set(y)))
